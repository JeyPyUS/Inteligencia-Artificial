# %% [markdown]
# # Taller en clase #1
# Generando numeros aleatorios en ptython.
# Objetivos:
# 1. Familiarizar al estudiante con la generación de numeros aleatorios de diferentes distribuciones en python.
# 2. Usar las herramientas de python de manejo de arreglos.
# 3. Usar las herramientas de generación de gráficas de python.
# ## Entrega
# En U-virtual, antes de la siguiente clase en el link designado como Taller en clase 1.

# %%
import numpy  #as np# si no lo tiene instalado por favor correr en su consola         $pip install numpy
import scipy #as sp# si no lo tiene instalado por favor correr en su consola         $pip install scipy
import matplotlib #si no lo tiene instalado por favor correr  en su consola   $pip install matplotlib
import matplotlib.pyplot as plt

# %% [markdown]
# ## Primer punto Distribuciones discretas.
# 1. Cree un arreglo de N muestras con N a su selección, pero mayor a 1000, de números distribuidos con las correspondientes distribuciones, para cada arreglo de números:
# 1. Grafique los números aleatorios,
# 2. Ordene de menor a mayor y grafique,
# 4. Encuentre los valores teoricos de media y varianza, y comparelos con los estimados.

# %%
#Para todas las simulaciones:
N=50000
m=300
numpy.random.seed(seed=2**32 - 1)#Para fijar una semilla para los experimentos y que los numeros generados siempre sean los mismos en cada corrida completa de este fuente.

# %%
# bernoulli con cierto p entre 0 y 1
p=0.3
from scipy.stats import bernoulli
mean, var, skew, kurt = bernoulli.stats(p, moments='mvsk')
print("Media:",mean,"Varianza:",var,"Skewness:",skew,"Kurtosis:",kurt)
r = bernoulli.rvs(p, size=N)
#ver https://docs.scipy.org/doc/scipy-0.14.0/reference/stats.html
plt.plot(r)
plt.title(str(N)+" puntos distribuidos bernoulli con p="+str(p))
plt.show()
# Out:
# Media: 0.3 Varianza: 0.21 Skewness: 0.8728715609439694 Kurtosis: -1.2380952380952381

# %%
r.sort()
plt.plot(r)
plt.title(str(N)+" puntos distribuidos bernoulli ordenados con p="+str(p))
plt.show()

# %%
plt.hist(r, bins = m)
plt.title("Histograma de los "+str(N)+" puntos distribuidos bernoulli con p="+str(p))
plt.show()
print("Note que hasta ahora no sabemos el tipo de nuestro arreglo r:")
print(type(r))
print("Vamos a hallar algunas estimaciones de estadisticas de r")
# ver https://numpy.org/doc/stable/reference/routines.statistics.html 
avg=r.mean()
varest=r.var()
print("Los valores teoricos de la media y varianza para la bernoulli con p=",p,"son u=" ,mean,"var=",var)
print("Los valores estimados en nuestro experimento de la media y varianza para la bernoulli con p=",p,"son u_est=" ,avg,"var_est=",varest)
# Out:
# Note que hasta ahora no sabemos el tipo de nuestro arreglo r:
# <class 'numpy.ndarray'>
# Vamos a hallar algunas estimaciones de estadisticas de r
# Los valores teoricos de la media y varianza para la bernoulli con p= 0.3 son u= 0.3 var= 0.21
# Los valores estimados en nuestro experimento de la media y varianza para la bernoulli con p= 0.3 son u_est= 0.29776 var_est= 0.20909898240000002

# %%
# binomial con cierto p entre 0 y 1 y cierto n
n,p = 10, 0.5
from scipy.stats import binom
mean, var, skew, kurt = binom.stats(n, p, moments='mvsk')
print("Media:",mean,"Varianza:",var,"Skewness:",skew,"Kurtosis:",kurt)
r = binom.rvs(n, p, size=N)
plt.plot(r)
plt.title(str(N)+" puntos con distribución binomial con n="+str(n)+" y p="+str(p))
plt.show()
# Out:
# Media: 5.0 Varianza: 2.5 Skewness: 0.0 Kurtosis: -0.2

# %%
r.sort()
plt.plot(r)
plt.title(str(N)+" puntos con distribución binomial ordenados con n="+str(n)+" y p="+str(p))
plt.show()

# %%
plt.hist(r, bins = m)
plt.title("Histograma de los "+str(N)+" puntos con distribución binomial con n="+str(n)+" y p="+str(p))
plt.show()
print("Vamos a hallar algunas estimaciones de estadisticas de r")
avg=r.mean()
varest=r.var()
print("Los valores teóricos de la media y varianza, para la binomial, con n =",n,"y p =",p,"son:")
print("u =",mean,"y var =",var)
print("Los valores estimados en nuestro experimento de la media y varianza, para la binomial, con n =",n,"y p =",p,"son:")
print("u_est =" ,avg,"y var_est =",varest)
# Out:
# Vamos a hallar algunas estimaciones de estadisticas de r
# Los valores teóricos de la media y varianza, para la binomial, con n = 10 y p = 0.5 son:
# u = 5.0 y var = 2.5
# Los valores estimados en nuestro experimento de la media y varianza, para la binomial, con n = 10 y p = 0.5 son:
# u_est = 4.99376 y var_est = 2.4978410624000005

# %%
# Geométrica con cierto p entre 0 y 1
p = 0.3
from scipy.stats import geom
mean, var, skew, kurt = geom.stats(p, moments='mvsk')
print("Media:",mean,"Varianza:",var,"Skewness:",skew,"Kurtosis:",kurt)
r = geom.rvs(p, size=N)
plt.plot(r)
plt.title(str(N)+" puntos con distribución geométrica con p="+str(p))
plt.show()
# Out:
# Media: 3.3333333333333335 Varianza: 7.777777777777779 Skewness: 2.031888635868469 Kurtosis: 6.128571428571429

# %%
r.sort()
plt.plot(r)
plt.title(str(N)+" puntos con distribución geométrtica ordenados con p="+str(p))
plt.show()

# %%
plt.hist(r, bins = m)
plt.title("Histograma de los "+str(N)+" puntos con distribución geométrica con p="+str(p))
plt.show()
print("Vamos a hallar algunas estimaciones de estadísticas de r")
avg=r.mean()
varest=r.var()
print("Los valores teóricos de la media y varianza, para la geométrica, con p =",p,"son:")
print("u =",mean,"y var =",var)
print("Los valores estimados en nuestro experimento de la media y varianza, para la geométrica, con p =",p,"son:")
print("u_est =" ,avg,"y var_est =",varest)
# Out:
# Vamos a hallar algunas estimaciones de estadísticas de r
# Los valores teóricos de la media y varianza, para la geométrica, con p = 0.3 son:
# u = 3.3333333333333335 y var = 7.777777777777779
# Los valores estimados en nuestro experimento de la media y varianza, para la geométrica, con p = 0.3 son:
# u_est = 3.32438 y var_est = 7.6928776156000005

# %%
# Poisson con cierto Lamnda L
L = 5
from scipy.stats import poisson
mean, var, skew, kurt = poisson.stats(L, moments='mvsk')
print("Media:",mean,"Varianza:",var,"Skewness:",skew,"Kurtosis:",kurt)
r = poisson.rvs(p, size=N)
plt.plot(r)
plt.title(str(N)+" puntos con distribución de Poisson con L="+str(L))
plt.show()
# Out:
# Media: 5.0 Varianza: 5.0 Skewness: 0.4472135954999579 Kurtosis: 0.2

# %%
r.sort()
plt.plot(r)
plt.title(str(N)+" puntos con distribución de Poison ordenados con L="+str(L))
plt.show()

# %%
plt.hist(r, bins = m)
plt.title("Histograma de los "+str(N)+" puntos con distribución de Poisson con L="+str(L))
plt.show()
print("Vamos a hallar algunas estimaciones de estadísticas de r")
avg=r.mean()
varest=r.var()
print("Los valores teóricos de la media y varianza, para la Poisson, con L =",L,"son:")
print("u =",mean,"y var =",var)
print("Los valores estimados en nuestro experimento de la media y varianza, para la Poisson, con L =",L,"son:")
print("u_est =" ,avg,"y var_est =",varest)
# Out:
# Vamos a hallar algunas estimaciones de estadísticas de r
# Los valores teóricos de la media y varianza, para la Poisson, con L = 5 son:
# u = 5.0 y var = 5.0
# Los valores estimados en nuestro experimento de la media y varianza, para la Poisson, con L = 5 son:
# u_est = 0.29516 y var_est = 0.29584057439999994

# %%
#Binomial negativa con parámetro p después de s fallos
s,p = 5,0.5
from scipy.stats import nbinom
mean, var, skew, kurt = nbinom.stats(s, p, moments='mvsk')
print("Media:",mean,"Varianza:",var,"Skewness:",skew,"Kurtosis:",kurt)
r = poisson.rvs(p, size=N)
plt.plot(r)
plt.title(str(N)+" puntos con distribución binomial negativa con s="+str(s)+" y p="+str(p))
plt.show()
# Out:
# Media: 5.0 Varianza: 10.0 Skewness: 0.9486832980505138 Kurtosis: 1.3

# %%
r.sort()
plt.plot(r)
plt.title(str(N)+" puntos con distribución binomial negativa ordenados con s="+str(s)+" y p="+str(p))
plt.show()

# %%
plt.hist(r, bins = m)
plt.title("Histograma de los "+str(N)+" puntos con distribución binomial negativa con s="+str(s)+" y p="+str(p))
plt.show()
print("Vamos a hallar algunas estimaciones de estadísticas de r")
avg=r.mean()
varest=r.var()
print("Los valores teóricos de la media y varianza, para la binomial negativa, con s =",s," y p =",p,"son:")
print("u =",mean,"y var =",var)
print("Los valores estimados en nuestro experimento de la media y varianza, para la binomial negativa, con s =",s," y p =",p,"son:")
print("u_est =" ,avg,"y var_est =",varest)
# Out:
# Vamos a hallar algunas estimaciones de estadísticas de r
# Los valores teóricos de la media y varianza, para la binomial negativa, con s = 5  y p = 0.5 son:
# u = 5.0 y var = 10.0
# Los valores estimados en nuestro experimento de la media y varianza, para la binomial negativa, con s = 5  y p = 0.5 son:
# u_est = 0.4986 y var_est = 0.4971180399999999

# %% [markdown]
# ## Segundo punto Distribuciones contínuas.

# %%
#Para todas las simulaciones:
N=1000
m=300
numpy.random.seed(seed=1314926535)#Para fijar una semilla para los experimentos y que los numeros generados siempre sean los mismos en cada corrida completa de este fuente.

# %%
# Normal de media 5 y desviación estandar 0.5
u=5
std=0.5
mean, var, skew, kurt = scipy.stats.norm.stats(moments='mvsk',loc=u,scale=std)
r = scipy.stats.norm.rvs (loc=u,scale=std, size=N)
#ver https://docs.scipy.org/doc/scipy-0.14.0/reference/stats.html
plt.plot(r)
plt.title(str(N)+" puntos distribuidos normales con media="+str(u)+" y std="+str(std))
plt.show()
r.sort()
plt.plot(r)
plt.title(str(N)+" puntos distribuidos normales ordenados con p="+str(p))
plt.show()
plt.hist(r, bins = m)
plt.title("Histograma de los "+str(N)+" puntos distribuidos normales con u="+str(u)+ " y std= "+str(std))
plt.show()
print("Note que hasta ahora no sabemos el tipo de nuestro arreglo r:")
print(type(r))
print("Vamos a hallar algunas estimaciones de estadisticas de r")
# ver https://numpy.org/doc/stable/reference/routines.statistics.html 
avg=r.mean()
varest=r.var()
print("Los valores teoricos de la media y varianza para la normal son u=" ,mean,"var=",var)
print("Los valores estimados en nuestro experimento de la media y varianza son u_est=" ,avg,"var_est=",varest)
# Out:
# Note que hasta ahora no sabemos el tipo de nuestro arreglo r:
# <class 'numpy.ndarray'>
# Vamos a hallar algunas estimaciones de estadisticas de r
# Los valores teoricos de la media y varianza para la normal son u= 5.0 var= 0.25
# Los valores estimados en nuestro experimento de la media y varianza son u_est= 5.0049846331611265 var_est= 0.2554557286078445

# %%
# Uniforme entre 0 y 255

from scipy.stats import uniform
mean, var, skew, kurt = uniform.stats(moments='mvsk')
r = uniform.rvs(loc=0, scale=255, size=N, random_state=None)
plt.plot(r)
plt.title(str(N)+" puntos con distribución uniforme")
plt.show()
r.sort()
plt.plot(r)
plt.title(str(N)+" puntos con distribución uniforme ordenados")
plt.show()
plt.hist(r, bins = m)
plt.title("Histograma de los "+str(N)+" puntos con distribución uniforme")
plt.show()
print("Vamos a hallar algunas estimaciones de estadisticas de r")
avg=r.mean()
varest=r.var()
print("Los valores teoricos de la media y varianza para la uniforme son:")
print("u=" ,mean,"var=",var)
print("Los valores estimados en nuestro experimento de la media y varianza son:")
print("u_est=" ,avg,"var_est=",varest)
# Out:
# Vamos a hallar algunas estimaciones de estadisticas de r
# Los valores teoricos de la media y varianza para la uniforme son:
# u= 0.5 var= 0.08333333333333333
# Los valores estimados en nuestro experimento de la media y varianza son:
# u_est= 130.906743344296 var_est= 5367.208464515891

# %%
# Exponencial con Lamnda L
L=0.3
from scipy.stats import exponpow
mean, var, skew, kurt = exponpow.stats(L, moments='mvsk')
r = exponpow.rvs(L, size=N)
plt.plot(r)
plt.title(str(N)+" puntos con distribución exponencial con L="+str(L))
plt.show()
r.sort()
plt.plot(r)
plt.title(str(N)+" puntos con distribución exponencial ordenados con L="+str(L))
plt.show()
plt.hist(r, bins = m)
plt.title("Histograma de los "+str(N)+" puntos con distribución exponencial con L="+str(L))
plt.show()
print("Vamos a hallar algunas estimaciones de estadísticas de r")
avg=r.mean()
varest=r.var()
print("Los valores teóricos de la media y varianza, para la exponencial, con L=", L,"son:")
print("u=" ,mean,"var=",var)
print("Los valores estimados en nuestro experimento de la media y varianza son:")
print("u_est=" ,avg,"var_est=",varest)
# Out:
# Vamos a hallar algunas estimaciones de estadísticas de r
# Los valores teóricos de la media y varianza, para la exponencial, con L= 0.3 son:
# u= 0.6168506348762715 var= 1.5648907938632868
# Los valores estimados en nuestro experimento de la media y varianza son:
# u_est= 0.6210323820328283 var_est= 1.6125750263028804

# %%
#Chi cuadrada con K grados de libertad
K=3.0
from scipy.stats import chi2
mean, var, skew, kurt = chi2.stats(K, moments='mvsk')
r = chi2.rvs(K, size=N)
plt.plot(r)
plt.title(str(N)+" puntos con distribución Chi cuadrado con K="+str(K))
plt.show()
r.sort()
plt.plot(r)
plt.title(str(N)+" puntos con distribución Chi cuadrado ordenados con K="+str(K))
plt.show()
plt.hist(r, bins = m)
plt.title("Histograma de los "+str(N)+" puntos con distribución Chi cuadrado con K="+str(K))
plt.show()
print("Vamos a hallar algunas estimaciones de estadísticas de r")
avg=r.mean()
varest=r.var()
print("Los valores teóricos de la media y varianza, para la Chi cuadrado, con K=", K,"son:")
print("u=" ,mean,"var=",var)
print("Los valores estimados en nuestro experimento de la media y varianza son:")
print("u_est=" ,avg,"var_est=",varest)
# Out:
# Vamos a hallar algunas estimaciones de estadísticas de r
# Los valores teóricos de la media y varianza, para la Chi cuadrado, con K= 3.0 son:
# u= 3.0 var= 6.0
# Los valores estimados en nuestro experimento de la media y varianza son:
# u_est= 3.067520944710233 var_est= 6.186165322138034

# %%
#Gamma con parametros k y theta t
k,t=2.54,0.43
from scipy.stats import gengamma
mean, var, skew, kurt = gengamma.stats(k, t, moments='mvsk')
r = exponpow.rvs(k, t, size=N)
plt.plot(r)
plt.title(str(N)+" puntos con distribución gamma con k="+str(k)+" y t="+str(t))
plt.show()
r.sort()
plt.plot(r)
plt.title(str(N)+" puntos con distribución gamma ordenados con k="+str(k)+" y t="+str(t))
plt.show()
plt.hist(r, bins = m)
plt.title("Histograma de los "+str(N)+" puntos con distribución gamma con k="+str(k)+" y t="+str(t))
plt.show()
print("Vamos a hallar algunas estimaciones de estadísticas de r")
avg=r.mean()
varest=r.var()
print("Los valores teóricos de la media y varianza, para la gamma, con k=", k,"y t=",t,"son:")
print("u=" ,mean,"var=",var)
print("Los valores estimados en nuestro experimento de la media y varianza son:")
print("u_est=" ,avg,"var_est=",varest)
# Out:
# Vamos a hallar algunas estimaciones de estadísticas de r
# Los valores teóricos de la media y varianza, para la gamma, con k= 2.54 y t= 0.43 son:
# u= 14.35967866460761 var= 548.8900307790022
# Los valores estimados en nuestro experimento de la media y varianza son:
# u_est= 1.1821746183414652 var_est= 0.06389262919322644
